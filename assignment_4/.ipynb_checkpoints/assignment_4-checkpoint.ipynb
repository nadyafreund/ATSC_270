# %% [markdown]
# # ASSIGNMENT #4 - SURFACE WEATHER DATA #
# Due: 31 March 2024 @ 11:59p

# %% [markdown]
# Purpose:\
# The purpose of this assignment is to continue to strengthen skills with reading in data by reading in surface observations from a text file.  The data is then plotted on a map to begin to familiarize with plotting weather data on maps.
#
# Overview:\
# In this assignment you will read in surface weather data, quality control that data, and plot that data .
#
#
# | | UPDATE TO YOUR INFORMATION |
# | :- | :- |
# | Created By | Jared W. Marquis |
# | Creation Date | 18 January 2024 |
# | Course | ATSC 270 - Computer Concepts in Meteorology |

# %%
### UPDATE TO YOUR INFORMATION ###
#information allowing anyone with the code to print the author and contact information
__author__="Nadya E. Freund"
__contact__="nadya.feund@und.edu"

# %% [markdown]
# ### IMPORT REQUIRED LIBRARIES ###

# %%
import numpy as np

import metpy.calc as mpcalc
from metpy.units import units
from metpy.plots import current_weather, sky_cover, StationPlot, simple_layout
from metpy.io import metar

import pandas as pd

import matplotlib.pyplot as plt

import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# ### OPEN OBSERVATIONS TEXT FILE ###
# Open the text file containing the surface observations using the metpy metar reader -> metar.parse_metar_file(filename).

# %%
filename='metar_20240112_2100.txt'
#fixing the date
data=metar.parse_metar_file(filename,year=2024,month=1)
#isolating data
print(data.loc['KGFK'])
# Out:
#            station_id  latitude  longitude  elevation           date_time  \
# station_id
# KGFK             KGFK     47.95     -97.18      258.0 2024-01-12 20:53:00
# KGFK             KGFK     47.95     -97.18      258.0 2024-01-12 21:36:00
#
#             wind_direction  wind_speed  wind_gust  visibility current_wx1  \
# station_id
# KGFK                 340.0        19.0        NaN    1609.344        BLSN
# KGFK                 340.0        22.0       28.0    1609.344        BLSN
#
#             ... air_temperature dew_point_temperature altimeter  \
# station_id  ...
# KGFK        ...           -17.0                 -22.0     30.03
# KGFK        ...           -18.0                 -22.0     30.03
#
#             current_wx1_symbol current_wx2_symbol  current_wx3_symbol  \
# station_id
# KGFK                        38                  0                   0
# KGFK                        38                  0                   0
#
#                                        remarks  air_pressure_at_sea_level  \
# station_id
# KGFK        AO2 SLP197 60000 T11721217 56004 $                    1021.05
# KGFK         AO2 PK WND 35028/2134 T11781217 $                    1021.19
#
#            eastward_wind  northward_wind
# station_id
# KGFK            6.498383      -17.854160
# KGFK            7.524443      -20.673238
#
# [2 rows x 31 columns]

# %% [markdown]
# ### REMOVE DATA THAT IS INCOMPLETE ###
# Just remove data with no wind direction or wind speed.

# %%
#getting rid of NaN values
data=data.dropna(how='any',subset=['wind_direction','wind_speed'])
print(data)
# Out:
#            station_id  latitude   longitude  elevation           date_time  \
# station_id
# KGYH             KGYH     34.75  -82.380000      292.0 2024-01-12 20:47:00
# KMFV             KMFV     37.63  -75.770000       15.0 2024-01-12 20:55:00
# KPLD             KPLD     40.45  -84.983333      282.0 2024-01-12 20:55:00
# KIKT             KIKT     28.52  -88.280000       25.0 2024-01-12 20:50:00
# PAKU             PAKU     70.31 -149.580000        2.0 2024-01-12 20:45:00
# ...               ...       ...         ...        ...                 ...
# OIYY             OIYY     31.90   54.280000     1236.0 2024-01-12 21:50:00
# ORNI             ORNI     31.98   44.400000       53.0 2024-01-14 21:00:00
# NFTV             NFTV    -18.57 -173.970000       71.0 2024-01-12 21:00:00
# NFTL             NFTL    -19.78 -174.330000        3.0 2024-01-12 21:00:00
# NFTF             NFTF    -21.23 -175.150000       38.0 2024-01-12 21:00:00
#
#             wind_direction  wind_speed  wind_gust  visibility current_wx1  \
# station_id
# KGYH                  60.0        12.0        NaN    4828.032         +RA
# KMFV                 100.0         6.0        NaN   16093.440         NaN
# KPLD                 130.0        10.0        NaN    8046.720         -SN
# KIKT                 240.0        22.0       32.0    4828.032          BR
# PAKU                 100.0        21.0        NaN    4828.032        BLSN
# ...                    ...         ...        ...         ...         ...
# OIYY                 120.0         4.0        NaN   10000.000         NaN
# ORNI                 240.0         7.0        NaN    6000.000         NaN
# NFTV                  90.0        15.0        NaN    9999.000       -SHRA
# NFTL                  90.0        22.0        NaN    9999.000         NaN
# NFTF                  90.0        16.0        NaN    9999.000         NaN
#
#             ... air_temperature dew_point_temperature altimeter  \
# station_id  ...
# KGYH        ...             7.0                   6.0     29.61
# KMFV        ...             9.0                   5.0     29.99
# KPLD        ...             1.0                   1.0     29.16
# KIKT        ...            23.0                  21.0     29.68
# PAKU        ...           -15.0                 -16.0     29.96
# ...         ...             ...                   ...       ...
# OIYY        ...            11.0                  -3.0     29.88
# ORNI        ...            11.0                   6.0     30.03
# NFTV        ...            28.0                  24.0     29.88
# NFTL        ...            29.0                  23.0     29.91
# NFTF        ...            27.0                  23.0     29.94
#
#             current_wx1_symbol current_wx2_symbol  current_wx3_symbol  \
# station_id
# KGYH                        65                 10                   0
# KMFV                         0                  0                   0
# KPLD                        71                  0                   0
# KIKT                        10                  0                   0
# PAKU                        38                 10                   0
# ...                        ...                ...                 ...
# OIYY                         0                  0                   0
# ORNI                         0                  0                   0
# NFTV                        80                  0                   0
# NFTL                         0                  0                   0
# NFTF                         0                  0                   0
#
#                   remarks  air_pressure_at_sea_level eastward_wind  \
# station_id
# KGYH                                         1003.81    -10.392305
# KMFV        AO2 T00890049                    1015.92     -5.908847
# KPLD            AO2 P0007                     989.18     -7.660444
# KIKT                  A01                    1005.29     19.052559
# PAKU                                         1014.89    -20.680963
# ...                   ...                        ...           ...
# OIYY                                         1012.21     -3.464102
# ORNI                                         1017.39      6.062178
# NFTV                                         1011.92    -15.000000
# NFTL                                         1013.28    -22.000000
# NFTF                                         1014.11    -16.000000
#
#             northward_wind
# station_id
# KGYH         -6.000000e+00
# KMFV          1.041889e+00
# KPLD          6.427876e+00
# KIKT          1.100000e+01
# PAKU          3.646612e+00
# ...                    ...
# OIYY          2.000000e+00
# ORNI          3.500000e+00
# NFTV         -9.184851e-16
# NFTL         -1.347111e-15
# NFTF         -9.797174e-16
#
# [8878 rows x 31 columns]

# %% [markdown]
# ### PLOT MAP ###

# %%
#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj=ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig=plt.figure(figsize=(10,10),dpi=100)

#add subplot with projection
ax=fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.BORDERS)

#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))

fig.tight_layout()

#save the map as empty_map.png
plt.savefig('empty_map.png')

# %% [markdown]
# ### PLOT A NEW MAP BUT ADD SURFACE OBS LOCATIONS ###

# %%
#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj=ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig=plt.figure(figsize=(10,10),dpi=100)

#add subplot with projection
ax=fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.BORDERS)

#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))


lon=data.longitude
lat=data.latitude

#plot surface obs using scatter plot
ax.scatter(lon,lat,transform=proj)
ax.scatter(lon,lat,transform=proj)

plt.scatter(data.longitude,data.latitude,transform=ccrs.PlateCarree())


fig.tight_layout()
#save the map as obs_locations.png
plt.savefig('obs_locations.png')

# %% [markdown]
# ### WAY TOO MANY OBS ###
# There are way too many obs for us to be able to actually see what the weather is.  We need to "thin" the obs in areas of very high densiy.
#
# We'll do this using the *metpy.calc.reduce_point_density* function.
#
# Find a density that works well for you.  The units for density are meters, so 100000 is roughly one observation/100km.

# %%
#first convert the lat/lon to map projection coordinates
locs=proj.transform_points(ccrs.PlateCarree(),data['longitude'].values,data['latitude'].values)

#now thin the data
data_thinned=data[mpcalc.reduce_point_density(locs,100000)]

#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj=ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig=plt.figure(figsize=(10,10),dpi=100)

#add subplot with projection
ax=fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.BORDERS)

#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))


lon=data_thinned.longitude
lat=data_thinned.latitude

#plot surface obs using scatter plot
ax.scatter(lon,lat,transform=proj)
ax.scatter(lon,lat,transform=proj)

plt.scatter(data_thinned.longitude,data_thinned.latitude,transform=ccrs.PlateCarree())


fig.tight_layout()

# %% [markdown]
# ### SAVE OBS LOCATIONS ON NEW MAP ###

# %%
#first convert the lat/lon to map projection coordinates
locs=proj.transform_points(ccrs.PlateCarree(),data['longitude'].values,data['latitude'].values)

#now thin the data
data_thinned=data[mpcalc.reduce_point_density(locs,100000)]

#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj=ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig=plt.figure(figsize=(10,10),dpi=100)

#add subplot with projection
ax=fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.BORDERS)

#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))


lon=data_thinned.longitude
lat=data_thinned.latitude

#plot surface obs using scatter plot
ax.scatter(lon,lat,transform=proj)
ax.scatter(lon,lat,transform=proj)

plt.scatter(data_thinned.longitude,data_thinned.latitude,transform=ccrs.PlateCarree())


fig.tight_layout()

#save the map as obs_locations_thinned.png
plt.savefig('obs_locations_thinned.png')

# %% [markdown]
# ### ONCE YOU'RE HAPPY WITH THE DENSITY, PLOT SURFACE STATIONS ###
# For this use the *StationPlot* object in metpy -> https://unidata.github.io/MetPy/latest/api/generated/metpy.plots.StationPlot.html

# %%
longitude=data_thinned['longitude'].values
latitude=data_thinned['latitude'].values
air_temperature=data_thinned['air_temperature'].values*units.degC
dew_point_temperature=data_thinned['dew_point_temperature'].values*units.degC
air_pressure_at_sea_level=data_thinned['air_pressure_at_sea_level'].values*units('millibar')

u,v=mpcalc.wind_components(data_thinned['wind_speed'].values*units('m/s'),data_thinned['wind_direction'].values*units.degree)

proj=ccrs.LambertConformal(central_longitude=-100,central_latitude=35,standard_parallels=[35])

#create the figure and an axes set to the projection
fig=plt.figure(figsize=(20, 10))
ax=fig.add_subplot(1,1,1,projection=proj)

#add some various map elements to the plot to make it recognizable
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.BORDERS)

#set plot bounds
ax.set_extent((-120,-75,23,50))

#specify the axes to draw on, as well as the lon/lat of the stations (with transform)
stationplot=StationPlot(ax, data_thinned['longitude'],data_thinned['latitude'],transform=ccrs.PlateCarree(),fontsize=9)

#the layout knows where everything should go, and things are standardized using the names of variables
#so, the layout pulls arrays out of `data_thinned` and plots them using `stationplot`
simple_layout.plot(stationplot,data_thinned)

#save the map as simple_surface_obs.png
plt.savefig('simple_surface_obs.png')
plt.show()

# %% [markdown]
# ### PLOT NORTHERN PLAINS ###
# Now we are going to focus on the Northern Great Plains and make a custom layout.<br>
# We will set the extent to 150W to 90W and 40N to 50N.<br>
# We will also need to re-thin the data since we will be zoomed in and can see more obs.<br><br>
# Data that will be plotted:<br>
#  - Temperature in the top left
#  - Dewpoint in bottom left
#  - Pressure in top right
#  - Station ID in bottom right
#  - Current weather on left
#  - Visibility in miles on far left
#  - Wind barb in black
#  - Wind gust barb in red

# %%
#create the figure and an axes set to the projection
fig=plt.figure(figsize=(20, 10))
ax=fig.add_subplot(1,1,1,projection=proj)

#add some various map elements to the plot to make it recognizable
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.BORDERS)

longitude=data_thinned['longitude'].values
latitude=data_thinned['latitude'].values
air_temperature=data_thinned['air_temperature'].values*units.degC
dew_point_temperature=data_thinned['dew_point_temperature'].values*units.degC
air_pressure_at_sea_level=data_thinned['air_pressure_at_sea_level'].values*units('millibar')
visibility=data_thinned['visibility'].values*units('meters')
visibility.ito('miles')

u2,v2=mpcalc.wind_components(data_thinned['wind_gust'].values*units('m/s'),data_thinned['wind_direction'].values*units.degree)
gust=data_thinned.wind_gust.values*units('knots')
gustuv=u2,v2,gust
u,v=mpcalc.wind_components(data_thinned['wind_speed'].values*units('m/s'),data_thinned['wind_direction'].values*units.degree)

proj=ccrs.LambertConformal(central_longitude=-95,central_latitude=35,standard_parallels=[35])

#set plot bounds
ax.set_extent((-105,-90,40,50))

#specify the axes to draw on, as well as the lon/lat of the stations (with transform)
stationplot=StationPlot(ax, data_thinned['longitude'],data_thinned['latitude'],transform=ccrs.PlateCarree(),fontsize=9)

#rethin data (90km works well)
data_thinned=data[mpcalc.reduce_point_density(locs,100000)]

stationplot.plot_parameter('NW',data_thinned['air_temperature'].values,color='red')
stationplot.plot_parameter('SW',data_thinned['dew_point_temperature'].values,color='darkgreen')

stationplot.plot_parameter((2,1),data_thinned['air_pressure_at_sea_level'].values)

#plot the cloud cover symbols using the `sky_cover` mapper to convert these values to font codes for the weather symbol
stationplot.plot_symbol('C',data_thinned['cloud_coverage'].values,sky_cover)

#plot current weather using the `current_weather` mapper to convert symbols
#current_weather=data_thinned('current_wx1_symbol','current_wx2_symbol','current_wx3_symbol')
#stationplot.plot_symbol('W',data_thinned['current_weather'].values,current_weather)

#wind barbs
stationplot.plot_barb(u2,v2,color='red')
stationplot.plot_barb(data_thinned['eastward_wind'].values, data_thinned['northward_wind'].values)
stationplot.plot_barb(u,v,color='black')

stationplot.plot_text((2,0),data_thinned['station_id'].values,color='darkblue')

#visibility
stationplot.plot_parameter((-3,0),data_thinned['visibility'].values,color='black')

plt.savefig('surface_obs.png')
plt.show()
